# %%
import pandas as pd

# %%
data = pd.read_csv('./ddanzi_total-2.tsv', encoding='utf-8', sep='\t\t', header=None, engine='python')

# %%
data.head()
# Out:
#    0                                                  1     2           3  \
# 0  1  자유게시판 테스트중입니다 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ...   관리자  2015-05-10
# 1  2                                          음.. 안녕하세요    시다  2015-05-10
# 2  3                                     자게이 난민 대피소인가요?   애러비  2015-05-10
# 3  4                                   ㄷㄷㄷㄷㄷ여기가 디스트릭트9?  낮해밤달  2015-05-10
# 4  5                                   아싸... 순위권 등극인가요?  아모피스  2015-05-10
#
#       4      5
# 0  11.0  12500
# 1   1.0   2479
# 2   NaN   2411
# 3   NaN   2541
# 4   NaN   2291

# %%
data.index
# Out:
# RangeIndex(start=0, stop=73717, step=1)

# %%
data.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df = data.loc[:,[1,2,3,4,5]].copy()

# %%
df.head()
# Out:
#                                                    1     2           3     4  \
# 0  자유게시판 테스트중입니다 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ...   관리자  2015-05-10  11.0
# 1                                          음.. 안녕하세요    시다  2015-05-10   1.0
# 2                                     자게이 난민 대피소인가요?   애러비  2015-05-10   NaN
# 3                                   ㄷㄷㄷㄷㄷ여기가 디스트릭트9?  낮해밤달  2015-05-10   NaN
# 4                                   아싸... 순위권 등극인가요?  아모피스  2015-05-10   NaN
#
#        5
# 0  12500
# 1   2479
# 2   2411
# 3   2541
# 4   2291

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 73687    False
# 73688    False
# 73689    False
# 73690    False
# 73691    False
# 73692    False
# 73693    False
# 73694    False
# 73695    False
# 73696    False
# 73697     True
# 73698    False
# 73699    False
# 73700    False
# 73701    False
# 73702    False
# 73703    False
# 73704    False
# 73705    False
# 73706    False
# 73707    False
# 73708    False
# 73709    False
# 73710    False
# 73711    False
# 73712    False
# 73713    False
# ...

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#                                                    1     2           3     4  \
# 0  자유게시판 테스트중입니다 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ...   관리자  2015-05-10  11.0
# 1                                          음.. 안녕하세요    시다  2015-05-10   1.0
# 2                                     자게이 난민 대피소인가요?   애러비  2015-05-10   NaN
# 3                                   ㄷㄷㄷㄷㄷ여기가 디스트릭트9?  낮해밤달  2015-05-10   NaN
# 4                                   아싸... 순위권 등극인가요?  아모피스  2015-05-10   NaN
#
#        5
# 0  12500
# 1   2479
# 2   2411
# 3   2541
# 4   2291

# %%
df.groupby(2).count().sort_values([3], ascending=[False])
# Out:
#                   1     3    4     5
# 2
# ▶◀雨天           1167  1167  224  1167
# 나박사다            956   956   50   956
# (˚∀˚)참치는TUNA    706   706   86   706
# 甲               641   641   26   641
# 후지지말입니다         586   586   50   586
# 꼼지오빠            554   554  124   554
# 석♥영             553   553  129   553
# ▶◀잠금몬           437   437   22   437
# 배부른기마민족         400   400  190   400
# 맬러뮤트보이          392   392   65   392
# 자연은블루베리         374   374   43   374
# 댓글관리위원회         368   368  100   368
# s(*^-^)♡”       361   361   29   361
# 프레세페♥별          359   359   42   359
# 푸른무지개           350   350   37   350
# 눈떠보니중년          350   350   28   350
# 플로리에♥           339   339   35   339
# Homopoeticus™   336   336   33   336
# i오가사와라          315   315   12   315
# 순낚              310   310   63   310
# 프로디지♥           297   297   43   297
# ㈜예수             296   296   52   296
# 미확인몸짱           296   296   43   296
# 아기둘참치♥          294   294   14   294
# ...

# %%
df.fillna(0)
# Out:
#                                                        1               2  \
# 0      자유게시판 테스트중입니다 ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ...             관리자
# 1                                              음.. 안녕하세요              시다
# 2                                         자게이 난민 대피소인가요?             애러비
# 3                                       ㄷㄷㄷㄷㄷ여기가 디스트릭트9?            낮해밤달
# 4                                       아싸... 순위권 등극인가요?            아모피스
# 5                                      오오 여기가 여기가 ㄷㄷㄷㄷㄷㄷ         자연은블루베리
# 6                                                ㅎㄷㄷㄷㄷㄷㄷ         SiMCiTY
# 7                                       딴지에 자게라니 ㄷㄷ ㄷ  ㄷ           행복한재호
# 8                                   여기가 자유게시판이 맞습니까? ㄷㄷㄷ           떡치기대장
# 9                                             ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ        ▶◀고소한레고밥
# 10                                      #일본불매 #탐수아 #탐사영상             탐수아
# 11                                              서버 느려졌다.             읊조림
# ...

# %%
df.to_csv("ddanzi-preprocess.tsv", mode='w', sep="|", header=None, index=None)
