# %%
import pandas as pd

# %%
data = pd.read_csv('./logs/1_10000.log', encoding='utf-8', sep='\t\t', header=None, engine='python')

# %%
data.head()
# Out:
#      0        1                                    2  \
# 0  [1]  4350535                               남양 볼매!
# 1  [1]  4350534        아니 정당한 전형 과정을 거쳐 대학, 의전 입학했는데
# 2  [1]  4350533  후쿠시마 해수가 지구를 한바퀴 돌아온다는 머저리가 아직도 있음?
# 3  [1]  4350532                   근데 남이사 ㄴㅇ 불매를 하든말든
# 4  [1]  4350531          남양 F&B에서 환타도 만들었다면서요~~~~???
#
#                                                    3               4  \
# 0  http://www.ddanzi.com/index.php?mid=free&docum...          탈퇴하고싶다
# 1  http://www.ddanzi.com/index.php?mid=free&docum...  Pizzicato_Five
# 2  http://www.ddanzi.com/index.php?mid=free&docum...           티르💬☄🈁
# 3  http://www.ddanzi.com/index.php?mid=free&docum...            아이사타
# 4  http://www.ddanzi.com/index.php?mid=free&docum...         사소함의소중함
#
#           5   6   7
# 0  17:34:44 NaN   0
# 1  17:34:42 NaN   0
# 2  17:33:55 NaN  48
# 3  17:33:47 NaN  15
# 4  17:33:45 NaN  16

# %%
data.index
# Out:
# RangeIndex(start=0, stop=73717, step=1)

# %%
data.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df = data.loc[:,[2,3,4,5,6,7]].copy()

# %%
df.head()
# Out:
#                                      2  \
# 0                               남양 볼매!
# 1        아니 정당한 전형 과정을 거쳐 대학, 의전 입학했는데
# 2  후쿠시마 해수가 지구를 한바퀴 돌아온다는 머저리가 아직도 있음?
# 3                   근데 남이사 ㄴㅇ 불매를 하든말든
# 4          남양 F&B에서 환타도 만들었다면서요~~~~???
#
#                                                    3               4  \
# 0  http://www.ddanzi.com/index.php?mid=free&docum...          탈퇴하고싶다
# 1  http://www.ddanzi.com/index.php?mid=free&docum...  Pizzicato_Five
# 2  http://www.ddanzi.com/index.php?mid=free&docum...           티르💬☄🈁
# 3  http://www.ddanzi.com/index.php?mid=free&docum...            아이사타
# 4  http://www.ddanzi.com/index.php?mid=free&docum...         사소함의소중함
#
#           5   6   7
# 0  17:34:44 NaN   0
# 1  17:34:42 NaN   0
# 2  17:33:55 NaN  48
# 3  17:33:47 NaN  15
# 4  17:33:45 NaN  16

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9970    False
# 9971    False
# 9972    False
# 9973    False
# 9974    False
# 9975    False
# 9976    False
# 9977    False
# 9978    False
# 9979    False
# 9980    False
# 9981    False
# 9982    False
# 9983    False
# 9984    False
# 9985    False
# 9986    False
# 9987    False
# 9988    False
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# 9994    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# ...

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#                                      2  \
# 0                               남양 볼매!
# 1        아니 정당한 전형 과정을 거쳐 대학, 의전 입학했는데
# 2  후쿠시마 해수가 지구를 한바퀴 돌아온다는 머저리가 아직도 있음?
# 3                   근데 남이사 ㄴㅇ 불매를 하든말든
# 4          남양 F&B에서 환타도 만들었다면서요~~~~???
#
#                                                    3               4  \
# 0  http://www.ddanzi.com/index.php?mid=free&docum...          탈퇴하고싶다
# 1  http://www.ddanzi.com/index.php?mid=free&docum...  Pizzicato_Five
# 2  http://www.ddanzi.com/index.php?mid=free&docum...           티르💬☄🈁
# 3  http://www.ddanzi.com/index.php?mid=free&docum...            아이사타
# 4  http://www.ddanzi.com/index.php?mid=free&docum...         사소함의소중함
#
#           5   6   7
# 0  17:34:44 NaN   0
# 1  17:34:42 NaN   0
# 2  17:33:55 NaN  48
# 3  17:33:47 NaN  15
# 4  17:33:45 NaN  16

# %%
df.groupby(4).count().sort_values([3], ascending=[False])
# Out:
#                 2    3    5   6    7
# 4
# ▶◀雨天☔️        233  233  233  86  233
# 티르💬☄🈁         132  132  132  32  132
# (N☢️니뽕)모냥     105  105  105  81  105
# 푸른무지개🌈😼😸😺      99   99   99  78   99
# [N🔴]벨로나        99   99   99  74   99
# GAsinaya       91   91   91  61   91
# 함부로애틋하게~🎗      66   66   66  22   66
# [N🔴]순땡이        62   62   62  55   62
# WANI           60   60   60  41   60
# 행성X            60   60   60  25   60
# 럭키7            57   57   57  45   57
# 🎗로드마리🔪🐈🍽🚴♀️    56   56   56  31   56
# 🇰🇷Zone         55   55   55  33   55
# 주루사卍이글스님       52   52   52  16   52
# [N🔴]더불어2D당대표   52   52   52  29   52
# TMI            51   51   51  16   51
# blur.          51   51   51  33   51
# [N🔴]테디™        50   50   50  30   50
# 하베스트           50   50   50  44   50
# (˚∀˚)참치는TUNA   47   47   47  40   47
# 아이유남편™         47   47   47  13   47
# 임가르시아🍖         45   45   45  32   45
# 너말야그레이섹이야🚗     42   42   42  16   42
# 홀리파워           41   41   41  35   41
# ...

# %%
df = df.fillna(0)

# %%
df.to_csv("ddanzi-preprocess.tsv", mode='w', sep="|", header=None, index=None)

# %%
df.values.tolist()
# Out:
# [['남양 볼매!',
#   'http://www.ddanzi.com/index.php?mid=free&document_srl=572536845',
#   '탈퇴하고싶다',
#   '17:34:44',
#   0.0,
#   0],
#  ['아니 정당한 전형 과정을 거쳐 대학, 의전 입학했는데',
#   'http://www.ddanzi.com/index.php?mid=free&document_srl=572537184',
#   'Pizzicato_Five',
#   '17:34:42',
#   0.0,
#   0],
#  ['후쿠시마 해수가 지구를 한바퀴 돌아온다는 머저리가 아직도 있음?',
#   'http://www.ddanzi.com/index.php?mid=free&document_srl=572537035',
#   '티르💬☄🈁',
#   '17:33:55',
#   0.0,
#   48],
#  ['근데 남이사 ㄴㅇ 불매를 하든말든',
#   'http://www.ddanzi.com/index.php?mid=free&document_srl=572537008',
#   '아이사타',
#   '17:33:47',
#   0.0,
#   15],
#  ['남양 F&B에서 환타도 만들었다면서요~~~~???',
#   'http://www.ddanzi.com/index.php?mid=free&document_srl=572537000',
#   '사소함의소중함',
#   '17:33:45',
#   0.0,
#   16],
#  ['북한 철도는 정비할곳이 한두곳이 아니라서...',
#   'http://www.ddanzi.com/index.php?mid=free&document_srl=572536989',
#   '▶◀친절한밀덕후™',
#   '17:33:43',
#   0.0,
#   20],
#  ['일본 쪽바리들 배가 우리나라에 와서 일본해수를 버린다는 뉴스를 보니....  ㅂㄷㅂㄷㅂㄷㅂㄷ',
# ...
